# %% [markdown]
# <a href="https://colab.research.google.com/github/gshaurya27/SOC-26---Face-Ageing-Model/blob/main/02_tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

# %%
#initisializing
x = tf.constant(4, shape=(1,1), dtype=tf.float32)
x = tf.constant([[1,2,3],[4,5,6]]) #2 by 3 matrix
x = tf.ones((3,3))
x = tf.eye(3) # eye for Identity mat
x = tf
print(x)
#mathematical ope

# indexing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1896/467690514.py in <cell line: 0>()
#       3 #x = tf.constant([[1,2,3],[4,5,6]]) #2 by 3 matrix
#       4 #x = tf.ones((3,3))
# ----> 5 x = tf.eye(3)
#       6
#       7 print(x)
#
# NameError: name 'tf' is not defined
